# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Navdeep/Desktop/Navdeep @ UTD/Self learn python/StudentsPerformance.csv")

# %%
#1 How to understand the data

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
#Cleaning the data for Exploratory Data Analysis

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Dropping the redundant data

# %%
###Why the axis=1???
student = data.drop(['race/ethnicity', 'parental level of education'], axis=1)

# %%
student.head()
# Out:
#    gender         lunch test preparation course  math score  reading score  \
# 0  female      standard                    none          72             72
# 1  female      standard               completed          69             90
# 2  female      standard                    none          90             95
# 3    male  free/reduced                    none          47             57
# 4    male      standard                    none          76             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
#Relationship analysis

# %%
print(type('female'))
# Out:
# <class 'str'>

# %%
sns.heatmap(corelation, xticklabels= corelation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 sns.heatmap(corelation, xticklabels= corelation)
#
# NameError: name 'corelation' is not defined

# %%
print(int('female'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(int('female'))
#
# ValueError: invalid literal for int() with base 10: 'female'

# %%
print(type('female'))
# Out:
# <class 'str'>

# %%
students= students.replace(to_replace=['male', 'female'], value=[0, 1], )

# %%
print(type('gender'))
# Out:
# <class 'str'>

# %%
print(int('gender'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(int('gender'))
#
# ValueError: invalid literal for int() with base 10: 'gender'

# %%
students= float('female')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 students= float('female')
#
# ValueError: could not convert string to float: 'female'

# %%
student=float('gender')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 student=float('gender')
#
# ValueError: could not convert string to float: 'gender'

# %%
corelation = student.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 corelation = student.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
student
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
data='female'
new_student=float('female')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 data='female'
# ----> 2 new_student=float('female')
#
# ValueError: could not convert string to float: 'female'

# %%
student = [float(str(i).replace(",", "")) for i in data["student"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 student = [float(str(i).replace(",", "")) for i in data["student"]]
#
# TypeError: string indices must be integers, not 'str'

# %%
data["student"] = data['student'].str.replace(' ', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 data["student"] = data['student'].str.replace(' ', '').astype(float)
#
# TypeError: string indices must be integers, not 'str'

# %%
df = pd.DataFrame({'student': ['female']})
df['student'] = pd.to_numeric(df['student'], errors='coerce')
print(df)
# Out:
#    student
# 0      NaN

# %%
df
# Out:
#    student
# 0      NaN

# %%
student
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
c= student.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 c= student.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
student= 'female'
students=float('female')
print(type('students'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 2
#       1 student= 'female'
# ----> 2 students=float('female')
#       3 print(type('students'))
#
# ValueError: could not convert string to float: 'female'

# %%
student='female'
print(float(student))
print(int(float(student)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 student='female'
# ----> 2 print(float(student))
#       3 print(int(float(student)))
#
# ValueError: could not convert string to float: 'female'

# %%
print(student.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 print(student.dtypes)
#
# AttributeError: 'str' object has no attribute 'dtypes'

# %%
student
# Out:
# 'female'

# %%
student
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
print(student.dtypes)
# Out:
# gender                     object
# lunch                      object
# test preparation course    object
# math score                  int64
# reading score               int64
# writing score               int64
# dtype: object

# %%
students=student.copy()
students['gender']=students['gender'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 2
#       1 students=student.copy()
# ----> 2 students['gender']=students['gender'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
student=(int(student.gender('female')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 student=(int(student.gender('female')))
#
# TypeError: 'Series' object is not callable

# %%
student['gender'] = student['gender'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 student['gender'] = student['gender'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
student
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    1
# Name: gender, Length: 1000, dtype: int64

# %%
student
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    1
# Name: gender, Length: 1000, dtype: int64

# %%
students
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 3      male  free/reduced                    none          47             57
# 4      male      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995  female      standard               completed          88             99
# 996    male  free/reduced                    none          62             55
# 997  female  free/reduced               completed          59             71
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
students
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0         1      standard                    none          72             72
# 1         1      standard               completed          69             90
# 2         1      standard                    none          90             95
# 3         0  free/reduced                    none          47             57
# 4         0      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995       1      standard               completed          88             99
# 996       0  free/reduced                    none          62             55
# 997       1  free/reduced               completed          59             71
# 998       1      standard               completed          68             78
# 999       1  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
corelation= students.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 corelation= students.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
students
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0         1      standard                    none          72             72
# 1         1      standard               completed          69             90
# 2         1      standard                    none          90             95
# 3         0  free/reduced                    none          47             57
# 4         0      standard                    none          76             78
# ..      ...           ...                     ...         ...            ...
# 995       1      standard               completed          88             99
# 996       0  free/reduced                    none          62             55
# 997       1  free/reduced               completed          59             71
# 998       1      standard               completed          68             78
# 999       1  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
df=students.drop(['lunch'], axis=1)

# %%
df
# Out:
#      gender test preparation course  math score  reading score  writing score
# 0         1                    none          72             72             74
# 1         1               completed          69             90             88
# 2         1                    none          90             95             93
# 3         0                    none          47             57             44
# 4         0                    none          76             78             75
# ..      ...                     ...         ...            ...            ...
# 995       1               completed          88             99             95
# 996       0                    none          62             55             55
# 997       1               completed          59             71             65
# 998       1               completed          68             78             77
# 999       1                    none          77             86             86
#
# [1000 rows x 5 columns]

# %%
df_2=df.replace(to_replace=['completed', 'none'], value=[0,1])

# %%
df_2
# Out:
#      gender  test preparation course  math score  reading score  writing score
# 0         1                        1          72             72             74
# 1         1                        0          69             90             88
# 2         1                        1          90             95             93
# 3         0                        1          47             57             44
# 4         0                        1          76             78             75
# ..      ...                      ...         ...            ...            ...
# 995       1                        0          88             99             95
# 996       0                        1          62             55             55
# 997       1                        0          59             71             65
# 998       1                        0          68             78             77
# 999       1                        1          77             86             86
#
# [1000 rows x 5 columns]

# %%
corelation=df_2.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels= corelation.columns
           ,annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(df_2)
# Out:
# C:\Users\Navdeep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(df_2)
# Out:
# <Axes: >

# %%
sns.relplot(x='math score', y='reading score', hue = 'gender', data=df_2)
# Out:
# C:\Users\Navdeep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(df_2['math score'])
# Out:
# C:\Users\Navdeep\AppData\Local\Temp\ipykernel_21244\16871423.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['math score'])
# <Axes: xlabel='math score', ylabel='Density'>

# %%
sns.displot(df_2['reading score'], bins= 20)
# Out:
# C:\Users\Navdeep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='math score', kind='box', data = df_2)
# Out:
# C:\Users\Navdeep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='reading score', kind='box', data=df_2)
# Out:
# C:\Users\Navdeep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
